# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz, process

pd.set_option("display.max_rows", None)

# %%
test_data = pd.read_csv('laptops_0-1499.csv')[['CPU', 'GPU']]
test_data.head()
# Out:
#                                        CPU                      GPU
# 0  Intel Core i7 13th Gen 1355U (1.70GHz)    Intel Iris Xe Graphics
# 1   Intel Core i7 13th Gen 1355U (1.70GHz)   Intel Iris Xe Graphics
# 2                        AMD Ryzen 5-7530U      AMD Radeon Graphics
# 3                       i7-1280P (1.80GHz)  Intel Iris Xe Graphics
# 4           Intel Celeron N4500 (1.10GHz)        Intel UHD Graphics

# %%
cpu_test = pd.DataFrame(test_data['CPU'].iloc[:50])['CPU'].apply(lambda x: x.lower())
# Out:
# 0    intel core i7 13th gen 1355u (1.70ghz)
# 1     intel core i7 13th gen 1355u (1.70ghz)
# 2                          amd ryzen 5-7530u
# 3                         i7-1280p (1.80ghz)
# 4             intel celeron n4500 (1.10ghz)
# Name: CPU, dtype: object

# %%
cpu_test.to_csv('map_cpu_test.csv')

# %%
gpu_test = pd.DataFrame(test_data['GPU'].iloc[:51])
gpu_test
# Out:
#                                    GPU
# 0               Intel Iris Xe Graphics
# 1               Intel Iris Xe Graphics
# 2                  AMD Radeon Graphics
# 3              Intel Iris Xe Graphics
# 4                   Intel UHD Graphics
# 5                   Intel UHD Graphics
# 6                  NVIDIA RTX 2000 ADA
# 7                  AMD Radeon Graphics
# 8               Intel Iris Xe Graphics
# 9               Intel Iris Xe Graphics
# 10                 AMD Radeon Graphics
# 11             Intel Iris Xe Graphics
# 12              Intel Iris Xe Graphics
# 13                 AMD Radeon Graphics
# 14                     NVIDIA RTX 3000
# 15              Intel Iris Xe Graphics
# 16                  Intel UHD Graphics
# 17            Intel Iris Plus Graphics
# 18              Intel Iris Xe Graphics
# 19              Intel Iris Xe Graphics
# 20                  Intel UHD Graphics
# 21                  Intel UHD Graphics
# 22             NVIDIA GeForce RTX 4050
# 23             NVIDIA GeForce RTX 4050
# 24             Intel Iris Xe Graphics
# 25              Intel Iris Xe Graphics
# 26              Intel Iris Xe Graphics
# 27              Intel Iris Xe Graphics
# 28  NVIDIA GeForce RTX 3060 Laptop GPU
# 29              Intel Iris Xe Graphics
# 30              Intel Iris Xe Graphics
# 31              Intel Iris Xe Graphics
# 32             NVIDIA GeForce RTX 4060
# 33             Intel Iris Xe Graphics
# 34              Intel Iris Xe Graphics
# 35              Intel Iris Xe Graphics
# 36                 AMD Radeon Graphics
# 37            Intel Iris Plus Graphics
# 38                                 NaN
# 39             NVIDIA GeForce RTX 4060
# 40              Intel Iris Xe Graphics
# 41                 AMD Radeon Graphics
# 42                  Intel UHD Graphics
# 43               Intel HD Graphics 620
# 44              Intel Iris Xe Graphics
# 45              Intel Iris Xe Graphics
# 46             NVIDIA GeForce RTX 2050
# 47                  Intel UHD Graphics
# 48              Intel UHD Graphics 615
# 49         NVIDIA GeForce RTX 4050 GPU
# 50              Intel Iris Xe Graphics

# %%
gpu_test = gpu_test.drop(38)
gpu_test
# Out:
#                                    GPU
# 0               Intel Iris Xe Graphics
# 1               Intel Iris Xe Graphics
# 2                  AMD Radeon Graphics
# 3              Intel Iris Xe Graphics
# 4                   Intel UHD Graphics
# 5                   Intel UHD Graphics
# 6                  NVIDIA RTX 2000 ADA
# 7                  AMD Radeon Graphics
# 8               Intel Iris Xe Graphics
# 9               Intel Iris Xe Graphics
# 10                 AMD Radeon Graphics
# 11             Intel Iris Xe Graphics
# 12              Intel Iris Xe Graphics
# 13                 AMD Radeon Graphics
# 14                     NVIDIA RTX 3000
# 15              Intel Iris Xe Graphics
# 16                  Intel UHD Graphics
# 17            Intel Iris Plus Graphics
# 18              Intel Iris Xe Graphics
# 19              Intel Iris Xe Graphics
# 20                  Intel UHD Graphics
# 21                  Intel UHD Graphics
# 22             NVIDIA GeForce RTX 4050
# 23             NVIDIA GeForce RTX 4050
# 24             Intel Iris Xe Graphics
# 25              Intel Iris Xe Graphics
# 26              Intel Iris Xe Graphics
# 27              Intel Iris Xe Graphics
# 28  NVIDIA GeForce RTX 3060 Laptop GPU
# 29              Intel Iris Xe Graphics
# 30              Intel Iris Xe Graphics
# 31              Intel Iris Xe Graphics
# 32             NVIDIA GeForce RTX 4060
# 33             Intel Iris Xe Graphics
# 34              Intel Iris Xe Graphics
# 35              Intel Iris Xe Graphics
# 36                 AMD Radeon Graphics
# 37            Intel Iris Plus Graphics
# 39             NVIDIA GeForce RTX 4060
# 40              Intel Iris Xe Graphics
# 41                 AMD Radeon Graphics
# 42                  Intel UHD Graphics
# 43               Intel HD Graphics 620
# 44              Intel Iris Xe Graphics
# 45              Intel Iris Xe Graphics
# 46             NVIDIA GeForce RTX 2050
# 47                  Intel UHD Graphics
# 48              Intel UHD Graphics 615
# 49         NVIDIA GeForce RTX 4050 GPU
# 50              Intel Iris Xe Graphics

# %%
gpu_test = gpu_test['GPU'].apply(lambda x: x.lower().replace('nvidia','').replace('amd','').strip())
gpu_test.shape
# Out:
# (50,)

# %%
gpu_test.to_csv('map_gpu_test.csv')

# %% [markdown]
# # LOAD THE MAPPING DICTIONARY

# %%
cpu_df = pd.read_csv('cpu_mark.csv', index_col = 0)
gpu_df = pd.read_csv('gpu_mark.csv', index_col = 0)
gpu_df.shape
# Out:
# (2486, 2)

# %%
cpu_name_list = [cpu_df['CPU Name'][idx].lower() for idx in cpu_df.index]
gpu_name_list = [gpu_df['GPU Name'][idx].lower() for idx in gpu_df.index]

# %% [markdown]
# # Implement test function

# %%
cpu_test = pd.read_csv("map_cpu_test.csv", index_col = 0)
gpu_test = pd.read_csv("map_gpu_test.csv",index_col = 0)
gpu_test.reset_index(inplace=True)

# %%
cpu_test.head()
# Out:
#                                        CPU                      CPU Label
# 0  intel core i7 13th gen 1355u (1.70ghz)             intel core i7 1355u
# 1   intel core i7 13th gen 1355u (1.70ghz)            intel core i7 1355u
# 2                        amd ryzen 5-7530u              amd ryzen 5 7530u
# 3                       i7-1280p (1.80ghz)            intel core i7 1280p
# 4           intel celeron n4500 (1.10ghz)   intel celeron n4500   1.10ghz

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

def mapping(s, slist):
    s2 = s.lower()
    found=[0, -1]
    for i in range(len(slist)):
        if s2 in slist[i]:
            found[0] = 100
            found[1] = i
            break
        acc=sum([fuzz.ratio(slist[i], s2),fuzz.partial_ratio(slist[i], s2),fuzz.token_sort_ratio(slist[i], s2),fuzz.token_set_ratio(slist[i], s2)])/4
#         acc=max(fuzz.ratio(slist[i], s2),fuzz.partial_ratio(slist[i], s2),fuzz.token_sort_ratio(slist[i], s2),fuzz.token_set_ratio(slist[i], s2))
        if found[0]<acc:
            found[0]=acc
            found[1]=i
    return found

# %%
def test_cpu(cpu_lst):
    count = 0
    for i in range(len(cpu_lst)):
        cpu_low = cpu_lst[i].lower()
        acc, pos = mapping(cpu_low, cpu_name_list)
        if cpu_name_list[pos].strip() == cpu_test['CPU Label'][i].strip():
            print('Label: ' + cpu_test['CPU Label'][i])
            print('Predict: ' + cpu_name_list[pos] + ' ==> ' + 'True')
            count += 1
        else:
            print('Label: ' + cpu_test['CPU Label'][i])
            print('Predict: ' + cpu_name_list[pos] + ' ==> ' + 'False')
    return count

def test_gpu(gpu_lst):
    count = 0
    for i in range(len(gpu_lst)):
        gpu_low = gpu_lst[i].lower()
        acc, pos = mapping(gpu_low, gpu_name_list)
        if gpu_name_list[pos].strip() == gpu_test['GPU Label'][i].strip():
            print('Label: ' + gpu_test['GPU Label'][i])
            print('Predict: ' + gpu_name_list[pos] + ' ==> ' + 'True')
            count += 1
        else:
            print('Label: ' + gpu_test['GPU Label'][i])
            print('Predict: ' + gpu_name_list[pos] + ' ==> ' + 'False')
    return count

# %%
cpu_lst = list(cpu_test['CPU'])
gpu_lst = list(gpu_test['GPU'])

# %%
cpu_acc = test_cpu(cpu_lst)
gpu_acc = test_gpu(gpu_lst)
# Out:
# Label: intel core i7 1355u
# Predict: intel core i7 1355u ==> True
# Label: intel core i7 1355u
# Predict: intel core i7 1355u ==> True
# Label: amd ryzen 5 7530u
# Predict: amd ryzen 5 7530u ==> True
# Label: intel core i7 1280p
# Predict: intel core i7 4860eq   1.80ghz ==> False
# Label: intel celeron n4500   1.10ghz
# Predict: intel celeron n4500   1.10ghz ==> True
# Label: intel celeron n4500   1.10ghz
# Predict: intel celeron n4500   1.10ghz ==> True
# Label: intel core i9 13950hx
# Predict: intel core i9 13950hx ==> True
# Label: amd ryzen 7 7730u
# Predict: amd ryzen 7 7730u ==> True
# Label: intel core i5 1235u
# Predict: intel core i5 1235u ==> True
# Label: intel core i7 1260p
# Predict: intel core i7 1260p ==> True
# Label: amd ryzen 5 5500u
# Predict: amd ryzen 5 5500u ==> True
# Label: intel core i5 1135g7   2.40ghz
# Predict: intel core i5 1135g7   2.40ghz ==> True
# Label: intel core i5 1235u
# Predict: intel core i5 1235u ==> True
# Label: amd ryzen 5 7530u
# Predict: amd ryzen 5 7530u ==> True
# Label: intel core i9 13950hx
# Predict: intel core i9 13950hx ==> True
# Label: intel core i5 13420h
# Predict: intel core i5 13420h ==> True
# Label: intel core i3 1215u
# Predict: intel core i3 1215u ==> True
# Label: intel core i9 7900x   3.30ghz
# Predict: intel core i9 13900h ==> False
# Label: intel core i5 1155g7   2.50ghz
# Predict: intel core i5 1155g7   2.50ghz ==> True
# Label: intel core i7 1360p
# Predict: intel core i7 1360p ==> True
# Label: intel core i3 1315u
# Predict: intel core i3 1315u ==> True
# Label: intel core i3 1115g4   3.00ghz
# Predict: intel core i3 1115g4   3.00ghz ==> True
# Label: intel core i7 13620h
# Predict: intel core i7 13620h ==> True
# Label: intel core i7 1360p
# Predict: intel core i7 1360p ==> True
# Label: intel core i7 1255u
# Predict: intel core i7 1255u ==> True
# Label: intel core i7 1360p
# Predict: intel core i7 1360p ==> True
# Label: intel core i7 1360p
# Predict: intel core i7 1360p ==> True
# Label: intel core i7 1260p
# Predict: intel core i7 1260p ==> True
# Label: intel core i7 11800h   2.30ghz
# Predict: intel core i7 11800h   2.30ghz ==> True
# Label: intel core i7 1195g7   2.90ghz
# Predict: intel core i7 1195g7   2.90ghz ==> True
# Label: intel core i5 1335u
# Predict: intel core i5 1335u ==> True
# Label: intel core i5 1335u
# Predict: intel core i5 1335u ==> True
# Label: intel core i9 13900h
# Predict: intel core i9 13900h ==> True
# Label: intel core i5 1135g7   2.40ghz
# Predict: intel core i5 1135g7   2.40ghz ==> True
# Label: intel core i7 13620h
# Predict: intel core i7 13620h ==> True
# Label: intel core i7 1280p
# Predict: intel core i7 1280p ==> True
# Label: amd ryzen 7 7730u
# Predict: amd ryzen 7 7730u ==> True
# Label: intel core i7 7y75   1.30ghz
# Predict: intel core i7 7y75   1.30ghz ==> True
# Label: intel core i5 1140g7   1.10ghz
# Predict: intel core i5 1140g7   1.10ghz ==> True
# Label: intel core i9 13900h
# Predict: intel core i9 13900h ==> True
# Label: intel core i5 1235u
# Predict: intel core i5 1235u ==> True
# Label: amd ryzen 5 5600h
# Predict: amd ryzen 5 5600h ==> True
# Label: intel core i3 1115g4   3.00ghz
# Predict: intel core i3 1115g4   3.00ghz ==> True
# Label: intel core i5 1340p
# Predict: intel core i5 1340p ==> True
# Label: intel core i5 12500h
# Predict: intel core i5 12500h ==> True
# Label: intel core i7 1260p
# Predict: intel core i7 1260p ==> True
# Label: intel core i5 13500h
# Predict: intel core i5 13500h ==> True
# Label: intel core i5 13500h
# Predict: intel core i5 13500h ==> True
# Label: intel core i3 10100y   1.30ghz
# Predict: intel core i3 10100y   1.30ghz ==> True
# Label: intel core i7 13700h
# Predict: intel core i7 13700h ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: radeont 680m ryzen 7 7735hs
# Predict: radeont 680m ryzen 7 7735hs ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: intel uhd graphics
# Predict: intel uhd graphics ==> True
# Label: intel uhd graphics
# Predict: intel uhd graphics ==> True
# Label: rtx 2000 ada generation laptop gpu
# Predict: rtx 2000 ada generation laptop gpu ==> True
# Label: radeon xpress 1100
# Predict: radeon xpress 1100 ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: radeon xpress 1100
# Predict: radeon ryzen 5 4600ge with radeon graphics ==> False
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: radeon xpress 1100
# Predict: radeon ryzen 5 4600ge with radeon graphics ==> False
# Label: quadro rtx 3000
# Predict: quadro rtx 3000 ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: intel uhd graphics
# Predict: intel uhd graphics ==> True
# Label: intel iris plus
# Predict: intel iris plus ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: intel uhd graphics
# Predict: intel uhd graphics ==> True
# Label: intel uhd graphics
# Predict: intel uhd graphics ==> True
# Label: geforce rtx 2050
# Predict: geforce rtx 4050 laptop gpu ==> False
# Label: geforce rtx 2050
# Predict: geforce rtx 4050 laptop gpu ==> False
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: geforce rtx 3060 laptop gpu
# Predict: geforce rtx 3060 laptop gpu ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: geforce rtx 4060
# Predict: geforce rtx 4060 ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: radeon xpress 1100
# Predict: radeon ryzen 5 4600ge with radeon graphics ==> False
# Label: intel iris plus
# Predict: intel iris plus ==> True
# Label: geforce rtx 4060
# Predict: geforce rtx 4060 ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: radeon xpress 1100
# Predict: radeon ryzen 5 4600ge with radeon graphics ==> False
# Label: intel uhd graphics
# Predict: intel uhd graphics ==> True
# Label: intel uhd graphics 620
# Predict: intel hd graphics 620 ==> False
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True
# Label: geforce rtx 2050
# Predict: geforce rtx 2050 ==> True
# Label: intel uhd graphics
# Predict: intel uhd graphics ==> True
# Label: intel uhd graphics 615
# Predict: intel uhd graphics 615 ==> True
# Label: geforce rtx 4050 laptop gpu
# Predict: geforce rtx 4050 laptop gpu ==> True
# Label: intel iris xe
# Predict: intel iris xe ==> True

# %%
print('Accuracy on CPU: '+ str(cpu_acc/50))
print('Accuracy on GPU: '+ str(gpu_acc/50))
# Out:
# Accuracy on CPU: 0.96
# Accuracy on GPU: 0.86
