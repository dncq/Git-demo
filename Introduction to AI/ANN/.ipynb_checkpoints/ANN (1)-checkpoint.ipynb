# %% [markdown]
# #                       Data preprocessing

# %%
pip install emnist

# %%
from emnist import list_datasets
list_datasets()

# %%
#Install EMIST library, import datasets of letters, Matplotlib

from emnist import list_datasets
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
from emnist import extract_training_samples
images, labels = extract_training_samples("letters")
images.shape
# Out:
# (124800, 28, 28)

# %%
import keras
import tensorflow as tf
from keras.datasets import mnist
from keras.layers import Dense # Dense layers are "fully connected" layers
from keras.models import Sequential # Documentation: https://keras.io/models/sequential/
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
my_data = images
my_label = labels
x_train, x_test,y_train, y_test = train_test_split(my_data,my_label,test_size = 0.2, random_state = 365)
print("Training data shape: ", x_train.shape) # (60000, 28, 28) -- 60000 images, each 28x28 pixels
print("Test data shape", x_test.shape) # (10000, 28, 28) -- 10000 images, each 28x28
print("y_train.shape =",y_train.shape)
# Flatten the images
image_vector_size = 28*28
x_train = x_train.reshape(x_train.shape[0], image_vector_size)
x_test = x_test.reshape(x_test.shape[0], image_vector_size)

image_size = 28*28 # 28*28
num_classes = 26 # ten unique digits

print(x_train.shape)
print(y_train.shape)
model = Sequential()

# The input layer requires the special input_shape parameter which should match
# the shape of our training data.
model.add(Dense(units=100, activation='relu', input_shape=(image_size,)))
model.add(Dense(units = 100, activation="linear"))
model.add(Dense(units = 100, activation="elu"))
model.add(Dense(units=num_classes+1, activation='softmax'))

model.summary()

# x_train = x_train.reshape(x_train.shape[0], image_vector_size)
# x_test = x_test.reshape(x_test.shape[0], image_vector_size)


model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=32, epochs=100, verbose=True, validation_split=.1)
loss, accuracy  = model.evaluate(x_test, y_test, verbose=True)

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='best')
plt.show()

print(f'Test loss: {loss:.3}')
# Out:
# Training data shape:  (99840, 28, 28)
# Test data shape (24960, 28, 28)
# y_train.shape = (99840,)
# (99840, 784)
# (99840,)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 100)               78500
#
#  dense_5 (Dense)             (None, 100)               10100
#
#  dense_6 (Dense)             (None, 100)               10100
#
#  dense_7 (Dense)             (None, 27)                2727
#
# =================================================================
# Total params: 101,427
# Trainable params: 101,427
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 2.9188 - accuracy: 0.2676 - val_loss: 1.4245 - val_accuracy: 0.5795
# Epoch 2/100
# 2808/2808 [==============================] - 8s 3ms/step - loss: 1.1082 - accuracy: 0.6690 - val_loss: 1.0109 - val_accuracy: 0.6991
# Epoch 3/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.8957 - accuracy: 0.7347 - val_loss: 0.8327 - val_accuracy: 0.7476
# Epoch 4/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.7968 - accuracy: 0.7624 - val_loss: 0.7766 - val_accuracy: 0.7766
# Epoch 5/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.7229 - accuracy: 0.7828 - val_loss: 0.7203 - val_accuracy: 0.7831
# Epoch 6/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.6650 - accuracy: 0.8011 - val_loss: 0.6670 - val_accuracy: 0.8083
# Epoch 7/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.6271 - accuracy: 0.8116 - val_loss: 0.6924 - val_accuracy: 0.8000
# Epoch 8/100
# 2808/2808 [==============================] - 10s 3ms/step - loss: 0.5909 - accuracy: 0.8220 - val_loss: 0.6585 - val_accuracy: 0.8093
# Epoch 9/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.5659 - accuracy: 0.8295 - val_loss: 0.6761 - val_accuracy: 0.8065
# Epoch 10/100
# 2808/2808 [==============================] - 10s 3ms/step - loss: 0.5435 - accuracy: 0.8356 - val_loss: 0.6294 - val_accuracy: 0.8141
# Epoch 11/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.5303 - accuracy: 0.8397 - val_loss: 0.6021 - val_accuracy: 0.8260
# Epoch 12/100
# 2808/2808 [==============================] - 10s 3ms/step - loss: 0.5149 - accuracy: 0.8441 - val_loss: 0.6044 - val_accuracy: 0.8257
# Epoch 13/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.4991 - accuracy: 0.8479 - val_loss: 0.6174 - val_accuracy: 0.8228
# Epoch 14/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.4874 - accuracy: 0.8500 - val_loss: 0.6000 - val_accuracy: 0.8336
# Epoch 15/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.4774 - accuracy: 0.8526 - val_loss: 0.6503 - val_accuracy: 0.8168
# Epoch 16/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.4704 - accuracy: 0.8550 - val_loss: 0.6145 - val_accuracy: 0.8279
# Epoch 17/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.4541 - accuracy: 0.8589 - val_loss: 0.5913 - val_accuracy: 0.8307
# Epoch 18/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.4490 - accuracy: 0.8608 - val_loss: 0.5875 - val_accuracy: 0.8340
# Epoch 19/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.4444 - accuracy: 0.8609 - val_loss: 0.5572 - val_accuracy: 0.8450
# Epoch 20/100
# 2808/2808 [==============================] - 9s 3ms/step - loss: 0.4403 - accuracy: 0.8633 - val_loss: 0.6174 - val_accuracy: 0.8340
# Epoch 21/100
# 2808/2808 [==============================] - 9s 3ms/step - loss: 0.4372 - accuracy: 0.8637 - val_loss: 0.6170 - val_accuracy: 0.8382
# Epoch 22/100
# 2808/2808 [==============================] - 9s 3ms/step - loss: 0.4354 - accuracy: 0.8663 - val_loss: 0.6509 - val_accuracy: 0.8275
# Epoch 23/100
# 2808/2808 [==============================] - 7s 3ms/step - loss: 0.4168 - accuracy: 0.8698 - val_loss: 0.6300 - val_accuracy: 0.8294
# Epoch 24/100
# 2808/2808 [==============================] - 7s 3ms/step - loss: 0.4208 - accuracy: 0.8681 - val_loss: 0.6186 - val_accuracy: 0.8359
# Epoch 25/100
# 2808/2808 [==============================] - 7s 2ms/step - loss: 0.4180 - accuracy: 0.8700 - val_loss: 0.6164 - val_accuracy: 0.8414
# Epoch 26/100
# 2808/2808 [==============================] - 7s 3ms/step - loss: 0.4104 - accuracy: 0.8720 - val_loss: 0.6728 - val_accuracy: 0.8229
# Epoch 27/100
# 2808/2808 [==============================] - 8s 3ms/step - loss: 0.4025 - accuracy: 0.8734 - val_loss: 0.6578 - val_accuracy: 0.8291
# Epoch 28/100
# 2808/2808 [==============================] - 9s 3ms/step - loss: 0.4018 - accuracy: 0.8743 - val_loss: 0.6414 - val_accuracy: 0.8281
# Epoch 29/100
# 2808/2808 [==============================] - 9s 3ms/step - loss: 0.3976 - accuracy: 0.8741 - val_loss: 0.6109 - val_accuracy: 0.8454
# Epoch 30/100
# 2808/2808 [==============================] - 9s 3ms/step - loss: 0.3946 - accuracy: 0.8760 - val_loss: 0.6521 - val_accuracy: 0.8347
# Epoch 31/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3914 - accuracy: 0.8766 - val_loss: 0.6336 - val_accuracy: 0.8382
# Epoch 32/100
# 2808/2808 [==============================] - 9s 3ms/step - loss: 0.3887 - accuracy: 0.8775 - val_loss: 0.6687 - val_accuracy: 0.8255
# Epoch 33/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.3954 - accuracy: 0.8766 - val_loss: 0.6499 - val_accuracy: 0.8316
# Epoch 34/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3799 - accuracy: 0.8796 - val_loss: 0.6368 - val_accuracy: 0.8395
# Epoch 35/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3912 - accuracy: 0.8782 - val_loss: 0.6636 - val_accuracy: 0.8359
# Epoch 36/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.3841 - accuracy: 0.8789 - val_loss: 0.6654 - val_accuracy: 0.8387
# Epoch 37/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.3839 - accuracy: 0.8802 - val_loss: 0.6578 - val_accuracy: 0.8428
# Epoch 38/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3798 - accuracy: 0.8818 - val_loss: 0.6489 - val_accuracy: 0.8403
# Epoch 39/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3768 - accuracy: 0.8816 - val_loss: 0.6606 - val_accuracy: 0.8350
# Epoch 40/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3694 - accuracy: 0.8837 - val_loss: 0.7475 - val_accuracy: 0.8229
# Epoch 41/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.3706 - accuracy: 0.8818 - val_loss: 0.6886 - val_accuracy: 0.8295
# Epoch 42/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.3666 - accuracy: 0.8860 - val_loss: 0.6863 - val_accuracy: 0.8325
# Epoch 43/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.3640 - accuracy: 0.8845 - val_loss: 0.6841 - val_accuracy: 0.8347
# Epoch 44/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3708 - accuracy: 0.8824 - val_loss: 0.7091 - val_accuracy: 0.8292
# Epoch 45/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.3587 - accuracy: 0.8860 - val_loss: 0.6729 - val_accuracy: 0.8350
# Epoch 46/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3495 - accuracy: 0.8877 - val_loss: 0.6658 - val_accuracy: 0.8451
# Epoch 47/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3603 - accuracy: 0.8874 - val_loss: 0.7156 - val_accuracy: 0.8252
# Epoch 48/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3577 - accuracy: 0.8859 - val_loss: 0.6744 - val_accuracy: 0.8343
# Epoch 49/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.3477 - accuracy: 0.8885 - val_loss: 0.6941 - val_accuracy: 0.8412
# Epoch 50/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3490 - accuracy: 0.8883 - val_loss: 0.6930 - val_accuracy: 0.8362
# Epoch 51/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.3436 - accuracy: 0.8896 - val_loss: 0.6818 - val_accuracy: 0.8384
# Epoch 52/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3456 - accuracy: 0.8903 - val_loss: 0.7328 - val_accuracy: 0.8317
# Epoch 53/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.3732 - accuracy: 0.8850 - val_loss: 0.7138 - val_accuracy: 0.8276
# Epoch 54/100
# 2808/2808 [==============================] - 10s 3ms/step - loss: 0.3443 - accuracy: 0.8901 - val_loss: 0.7072 - val_accuracy: 0.8348
# Epoch 55/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3399 - accuracy: 0.8907 - val_loss: 0.6950 - val_accuracy: 0.8388
# Epoch 56/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.3377 - accuracy: 0.8916 - val_loss: 0.7306 - val_accuracy: 0.8304
# Epoch 57/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3590 - accuracy: 0.8879 - val_loss: 0.7643 - val_accuracy: 0.8302
# Epoch 58/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3441 - accuracy: 0.8919 - val_loss: 0.6987 - val_accuracy: 0.8387
# Epoch 59/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3411 - accuracy: 0.8923 - val_loss: 0.7252 - val_accuracy: 0.8331
# Epoch 60/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3296 - accuracy: 0.8941 - val_loss: 0.7323 - val_accuracy: 0.8326
# Epoch 61/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.3288 - accuracy: 0.8943 - val_loss: 0.7303 - val_accuracy: 0.8336
# Epoch 62/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3436 - accuracy: 0.8918 - val_loss: 0.7518 - val_accuracy: 0.8421
# Epoch 63/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3354 - accuracy: 0.8938 - val_loss: 0.7446 - val_accuracy: 0.8420
# Epoch 64/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3370 - accuracy: 0.8935 - val_loss: 0.7534 - val_accuracy: 0.8276
# Epoch 65/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3380 - accuracy: 0.8917 - val_loss: 0.7435 - val_accuracy: 0.8362
# Epoch 66/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3676 - accuracy: 0.8885 - val_loss: 0.7303 - val_accuracy: 0.8363
# Epoch 67/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3273 - accuracy: 0.8949 - val_loss: 0.7418 - val_accuracy: 0.8370
# Epoch 68/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3415 - accuracy: 0.8924 - val_loss: 0.7254 - val_accuracy: 0.8394
# Epoch 69/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.3293 - accuracy: 0.8962 - val_loss: 0.7952 - val_accuracy: 0.8330
# Epoch 70/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3263 - accuracy: 0.8964 - val_loss: 0.7298 - val_accuracy: 0.8400
# Epoch 71/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3366 - accuracy: 0.8951 - val_loss: 0.7289 - val_accuracy: 0.8379
# Epoch 72/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3233 - accuracy: 0.8967 - val_loss: 0.7578 - val_accuracy: 0.8372
# Epoch 73/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3361 - accuracy: 0.8937 - val_loss: 0.7720 - val_accuracy: 0.8275
# Epoch 74/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3192 - accuracy: 0.8967 - val_loss: 0.7506 - val_accuracy: 0.8392
# Epoch 75/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3223 - accuracy: 0.8968 - val_loss: 0.7592 - val_accuracy: 0.8387
# Epoch 76/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3303 - accuracy: 0.8954 - val_loss: 0.7964 - val_accuracy: 0.8308
# Epoch 77/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3192 - accuracy: 0.8971 - val_loss: 0.7848 - val_accuracy: 0.8319
# Epoch 78/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3138 - accuracy: 0.8987 - val_loss: 0.7704 - val_accuracy: 0.8353
# Epoch 79/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3273 - accuracy: 0.8965 - val_loss: 0.8354 - val_accuracy: 0.8315
# Epoch 80/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3185 - accuracy: 0.8973 - val_loss: 0.8476 - val_accuracy: 0.8324
# Epoch 81/100
# 2808/2808 [==============================] - 10s 3ms/step - loss: 0.3370 - accuracy: 0.8953 - val_loss: 0.7730 - val_accuracy: 0.8336
# Epoch 82/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.3269 - accuracy: 0.8980 - val_loss: 0.8113 - val_accuracy: 0.8330
# Epoch 83/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.3505 - accuracy: 0.8936 - val_loss: 0.7872 - val_accuracy: 0.8368
# Epoch 84/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3056 - accuracy: 0.9014 - val_loss: 0.8405 - val_accuracy: 0.8331
# Epoch 85/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.3219 - accuracy: 0.8973 - val_loss: 0.8321 - val_accuracy: 0.8361
# Epoch 86/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3071 - accuracy: 0.9017 - val_loss: 0.7856 - val_accuracy: 0.8375
# Epoch 87/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3324 - accuracy: 0.8963 - val_loss: 0.8130 - val_accuracy: 0.8367
# Epoch 88/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3129 - accuracy: 0.8998 - val_loss: 0.8229 - val_accuracy: 0.8334
# Epoch 89/100
# 2808/2808 [==============================] - 10s 4ms/step - loss: 0.3077 - accuracy: 0.9008 - val_loss: 0.8078 - val_accuracy: 0.8362
# Epoch 90/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3688 - accuracy: 0.8890 - val_loss: 0.8162 - val_accuracy: 0.8319
# Epoch 91/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3058 - accuracy: 0.9006 - val_loss: 0.8319 - val_accuracy: 0.8337
# Epoch 92/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3347 - accuracy: 0.8972 - val_loss: 0.8700 - val_accuracy: 0.8243
# Epoch 93/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3340 - accuracy: 0.8979 - val_loss: 0.8351 - val_accuracy: 0.8329
# Epoch 94/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3190 - accuracy: 0.8995 - val_loss: 0.8509 - val_accuracy: 0.8338
# Epoch 95/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3075 - accuracy: 0.9003 - val_loss: 0.8160 - val_accuracy: 0.8384
# Epoch 96/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3118 - accuracy: 0.9008 - val_loss: 0.8857 - val_accuracy: 0.8353
# Epoch 97/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3049 - accuracy: 0.9022 - val_loss: 0.8547 - val_accuracy: 0.8352
# Epoch 98/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3079 - accuracy: 0.9018 - val_loss: 0.8334 - val_accuracy: 0.8358
# Epoch 99/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3516 - accuracy: 0.8965 - val_loss: 0.8762 - val_accuracy: 0.8370
# Epoch 100/100
# 2808/2808 [==============================] - 11s 4ms/step - loss: 0.3085 - accuracy: 0.9012 - val_loss: 0.8679 - val_accuracy: 0.8248
# 780/780 [==============================] - 2s 3ms/step - loss: 0.8860 - accuracy: 0.8233
# Test loss: 0.886

# %%
import pickle
with open('test_data.pickle','wb') as file:
    pickle.dump(my_data, file)

# %%
with open('test_label.pickle','wb') as file:
    pickle.dump(my_label, file)
