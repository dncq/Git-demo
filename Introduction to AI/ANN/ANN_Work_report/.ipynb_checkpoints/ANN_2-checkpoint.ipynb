# %% [markdown]
# # Libraries Import and Data Preparation

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\savag\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\savag\anaconda3\lib\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: pandas>=0.23 in c:\users\savag\anaconda3\lib\site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\savag\anaconda3\lib\site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\savag\anaconda3\lib\site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\savag\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\savag\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\savag\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\savag\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\savag\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\savag\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\savag\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\savag\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\savag\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\savag\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\savag\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\savag\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\savag\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\savag\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install emnist
# Out:
# Requirement already satisfied: emnist in c:\users\savag\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: numpy in c:\users\savag\anaconda3\lib\site-packages (from emnist) (1.21.5)
# Requirement already satisfied: requests in c:\users\savag\anaconda3\lib\site-packages (from emnist) (2.27.1)
# Requirement already satisfied: tqdm in c:\users\savag\anaconda3\lib\site-packages (from emnist) (4.64.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\savag\anaconda3\lib\site-packages (from requests->emnist) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\savag\anaconda3\lib\site-packages (from requests->emnist) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\savag\anaconda3\lib\site-packages (from requests->emnist) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\savag\anaconda3\lib\site-packages (from requests->emnist) (1.26.9)
# Requirement already satisfied: colorama in c:\users\savag\anaconda3\lib\site-packages (from tqdm->emnist) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\savag\anaconda3\lib\site-packages (2.10.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\savag\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: packaging in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (22.9.24)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: setuptools in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (61.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\savag\anaconda3\lib\site-packages (from tensorflow) (0.27.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\savag\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\savag\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.3.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\savag\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.33.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\savag\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\savag\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\savag\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\savag\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\savag\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\savag\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\savag\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\savag\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\savag\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\savag\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\savag\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\savag\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\savag\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\savag\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\savag\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\savag\anaconda3\lib\site-packages (from packaging->tensorflow) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2959 sha256=45abeb1fcce4d095324469579a04ca66ee1b543b0ed171d726b071d08517d83b
#   Stored in directory: c:\users\savag\appdata\local\pip\cache\wheels\f8\e0\3d\9d0c2020c44a519b9f02ab4fa6d2a4a996c98d79ab2f569fa1
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0.post1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Module for dataset
from emnist import extract_training_samples, extract_test_samples

# Module for building ANN
import keras
import tensorflow as tf
from keras.layers import Dense 
from keras.models import Sequential 

# Module for data preprocessing
from sklearn.model_selection import train_test_split
import numpy as np

#Module for result demonstration
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
# Extract data from EMNIST Balanced Dataset (131,600 samples in total)
test_data, test_label =  extract_test_samples("balanced")
train_data, train_label = extract_training_samples("balanced")

#Group training and testing data
x_data = np.concatenate((train_data,test_data))
y_label = np.concatenate((train_label,test_label))

#Convert data into 1D Numpy array 
image_vector_size = 784 
x_data = x_data.reshape(x_data.shape[0], image_vector_size)


# Min Max Scaling Data
x_data = x_data / 255

#Divide data into training and test set
x_train, x_test,y_train, y_test = train_test_split(x_data,y_label,test_size = 0.2,stratify = y_label)

# %% [markdown]
# # ANN construction and testing result

# %%
#Optimizer learning Rate
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01,
    decay_steps=10000,
    decay_rate=0.98)
optimizer = keras.optimizers.SGD(learning_rate=lr_schedule)

# Define Early Stopping after 3 epochs with no improvement 
callback = tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=3)

# ANN construction with 3 hidden layers
num_classes = 47
model = Sequential()
model.add(Dense(256,  activation='relu',input_shape=(image_vector_size,)))
model.add(Dense(256, activation='relu'))
model.add(Dense(units=num_classes, activation='softmax'))
model.compile(optimizer=keras.optimizers.SGD(learning_rate = lr_schedule), loss="sparse_categorical_crossentropy", metrics=['accuracy'])

# Print the details of the ANN
model.summary()

#Training and testing model
history = model.fit(x_train, y_train, batch_size=32, epochs=100, verbose=True, validation_split=.1) #0.1 of training set is used for validation
loss, accuracy  = model.evaluate(x_test, y_test, verbose=True)

# Graph of accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='best')
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 47)                12079
#
# =================================================================
# Total params: 278,831
# Trainable params: 278,831
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 1.9419 - accuracy: 0.5045 - val_loss: 1.2634 - val_accuracy: 0.6377
# Epoch 2/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 1.1510 - accuracy: 0.6738 - val_loss: 1.0412 - val_accuracy: 0.7035
# Epoch 3/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 0.9693 - accuracy: 0.7197 - val_loss: 0.9090 - val_accuracy: 0.7350
# Epoch 4/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 0.8480 - accuracy: 0.7509 - val_loss: 0.8069 - val_accuracy: 0.7591
# Epoch 5/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 0.7611 - accuracy: 0.7723 - val_loss: 0.7475 - val_accuracy: 0.7690
# Epoch 6/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 0.6975 - accuracy: 0.7897 - val_loss: 0.6935 - val_accuracy: 0.7882
# Epoch 7/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 0.6488 - accuracy: 0.8009 - val_loss: 0.6553 - val_accuracy: 0.7943
# Epoch 8/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 0.6101 - accuracy: 0.8109 - val_loss: 0.6386 - val_accuracy: 0.7985
# Epoch 9/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 0.5784 - accuracy: 0.8188 - val_loss: 0.6063 - val_accuracy: 0.8049
# Epoch 10/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 0.5528 - accuracy: 0.8250 - val_loss: 0.5853 - val_accuracy: 0.8157
# Epoch 11/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 0.5293 - accuracy: 0.8311 - val_loss: 0.5693 - val_accuracy: 0.8183
# Epoch 12/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 0.5096 - accuracy: 0.8366 - val_loss: 0.5592 - val_accuracy: 0.8229
# Epoch 13/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 0.4922 - accuracy: 0.8405 - val_loss: 0.5487 - val_accuracy: 0.8206
# Epoch 14/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 0.4766 - accuracy: 0.8459 - val_loss: 0.5385 - val_accuracy: 0.8266
# Epoch 15/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 0.4627 - accuracy: 0.8495 - val_loss: 0.5308 - val_accuracy: 0.8252
# Epoch 16/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 0.4506 - accuracy: 0.8521 - val_loss: 0.5246 - val_accuracy: 0.8304
# Epoch 17/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 0.4385 - accuracy: 0.8557 - val_loss: 0.5130 - val_accuracy: 0.8324
# Epoch 18/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 0.4277 - accuracy: 0.8583 - val_loss: 0.5108 - val_accuracy: 0.8306
# Epoch 19/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 0.4184 - accuracy: 0.8611 - val_loss: 0.5107 - val_accuracy: 0.8335
# Epoch 20/100
# 2961/2961 [==============================] - 5s 2ms/step - loss: 0.4097 - accuracy: 0.8635 - val_loss: 0.5034 - val_accuracy: 0.8354
# Epoch 21/100
# 1704/2961 [================>.............] - ETA: 2s - loss: 0.4051 - accuracy: 0.8648

# %% [markdown]
# # Details of Labels Accuracy

# %%
predict_x=model.predict(x_test) 
print(predict_x.shape)
classes_x=np.argmax(predict_x,axis=1)
print(classes_x.shape)
print(classification_report(y_test,classes_x))
# Out:
# 823/823 [==============================] - 1s 980us/step
# (26320, 47)
# (26320,)
#               precision    recall  f1-score   support
#
#            0       0.63      0.51      0.56       560
#            1       0.62      0.53      0.57       560
#            2       0.83      0.86      0.85       560
#            3       0.95      0.94      0.94       560
#            4       0.86      0.90      0.88       560
#            5       0.86      0.87      0.86       560
#            6       0.89      0.88      0.89       560
#            7       0.95      0.95      0.95       560
#            8       0.88      0.87      0.87       560
#            9       0.70      0.75      0.72       560
#           10       0.92      0.93      0.93       560
#           11       0.89      0.89      0.89       560
#           12       0.91      0.93      0.92       560
#           13       0.91      0.86      0.88       560
#           14       0.96      0.92      0.94       560
#           15       0.59      0.65      0.62       560
#           16       0.88      0.88      0.88       560
#           17       0.94      0.90      0.92       560
#           18       0.64      0.63      0.63       560
#           19       0.87      0.88      0.88       560
#           20       0.91      0.92      0.91       560
#           21       0.54      0.63      0.58       560
#           22       0.95      0.95      0.95       560
#           23       0.93      0.89      0.91       560
#           24       0.60      0.73      0.66       560
#           25       0.93      0.93      0.93       560
#           26       0.89      0.89      0.89       560
#           27       0.91      0.93      0.92       560
#           28       0.87      0.86      0.87       560
#           29       0.89      0.93      0.91       560
#           30       0.87      0.92      0.90       560
#           31       0.94      0.88      0.91       560
#           32       0.94      0.95      0.94       560
#           33       0.93      0.93      0.93       560
#           34       0.87      0.84      0.86       560
#           35       0.88      0.87      0.87       560
#           36       0.83      0.88      0.85       560
#           37       0.88      0.88      0.88       560
#           38       0.92      0.93      0.93       560
#           39       0.92      0.94      0.93       560
#           40       0.60      0.55      0.58       560
#           41       0.62      0.59      0.60       560
#           42       0.90      0.92      0.91       560
#           43       0.89      0.91      0.90       560
#           44       0.62      0.55      0.58       560
#           45       0.92      0.94      0.93       560
#           46       0.87      0.85      0.86       560
#
#     accuracy                           0.84     26320
#    macro avg       0.84      0.84      0.84     26320
# weighted avg       0.84      0.84      0.84     26320

# %% [markdown]
# # Confusion Matrix for accuracy metrics visualization

# %%
pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)
truth = y_test
CFM = confusion_matrix(truth, pred)
df_cm = pd.DataFrame(CFM)
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)
print(CFM)
# Out:
# 718/718 [==============================] - 1s 1ms/step
# [[550   0   0 ...   0   1   1]
#  [  1 479   0 ...   0   0   1]
#  [  0   2 510 ...   0   0   0]
#  ...
#  [  0   0   0 ... 500   2   0]
#  [  0   0   0 ...   4 532   3]
#  [  4   0   0 ...   0   3 497]]

# %% [markdown]
# # Saving trained model

# %%
model.save("m.hdf5")

# %% [markdown]
# # Load Model and Prediction

# %%
new_model = keras.models.load_model("m.hdf5")
new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 256)               200960
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  dense_5 (Dense)             (None, 47)                12079
#
# =================================================================
# Total params: 278,831
# Trainable params: 278,831
# Non-trainable params: 0
# _________________________________________________________________
